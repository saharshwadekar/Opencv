# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
img = cv.imread("lena.jpg")

# %%
cv.imshow("Girl",img)
cv.waitKey(0)
# Out:
# 48

# %%
plt.imshow(img)

# %%
#reading videos

# %%
capture = cv.VideoCapture("xmas.mp4")
while(True):
    isTrue,frame = capture.read()
    cv.imshow("Video",frame)
    
    if cv.waitKey(20) & 0xFF==ord('d'):
        break
capture.release()
cv.destroyWindows('p')
# Out:
# [ WARN:0@1219.888] global /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_506zufg7xt/croots/recipe/opencv-suite_1664548331847/work/modules/videoio/src/cap_gstreamer.cpp (862) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ERROR:0@1219.888] global /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_506zufg7xt/croots/recipe/opencv-suite_1664548331847/work/modules/videoio/src/cap.cpp (166) open VIDEOIO(GSTREAMER): raised OpenCV exception:
#
# OpenCV(4.6.0) /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_506zufg7xt/croots/recipe/opencv-suite_1664548331847/work/modules/core/src/utils/filesystem.cpp:580: error: (-213:The function/feature is not implemented)  in function 'exists'
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 6
#       3 isTrue,frame = capture.read()
#       4 cv.imshow("Video",frame)
# ----> 6 frame_resized = reScaleFrame(frame)
#       7 cv.imshow("Video_ReSized",frame_resized)
#       9 if cv.waitKey(20) & 0xFF==ord('d'):
#
# NameError: name 'reScaleFrame' is not defined
